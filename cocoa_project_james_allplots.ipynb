# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
csv_path = "flavors_of_cacao.csv"
flavors_cacao = pd.read_csv(csv_path)
flavors_cacao.head()
# Out:
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# 4          2015            70%            France    3.50
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %%
flavors_cacao.count()
# Out:
# Company \n(Maker-if known)           1795
# Specific Bean Origin\nor Bar Name    1795
# REF                                  1795
# Review\nDate                         1795
# Cocoa\nPercent                       1795
# Company\nLocation                    1795
# Rating                               1795
# Bean\nType                           1794
# Broad Bean\nOrigin                   1794
# dtype: int64

# %%
flavors_cacao.dtypes
# Out:
# Company \n(Maker-if known)            object
# Specific Bean Origin\nor Bar Name     object
# REF                                    int64
# Review\nDate                           int64
# Cocoa\nPercent                        object
# Company\nLocation                     object
# Rating                               float64
# Bean\nType                            object
# Broad Bean\nOrigin                    object
# dtype: object

# %%
flavors_cacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
# Company
# (Maker-if known)           1795 non-null object
# Specific Bean Origin
# or Bar Name    1795 non-null object
# REF                                 1795 non-null int64
# Review
# Date                         1795 non-null int64
# Cocoa
# Percent                       1795 non-null object
# Company
# Location                    1795 non-null object
# Rating                              1795 non-null float64
# Bean
# Type                           1794 non-null object
# Broad Bean
# Origin                   1794 non-null object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
flavors_cacao.columns
# Out:
# Index(['Company \n(Maker-if known)', 'Specific Bean Origin\nor Bar Name',
#        'REF', 'Review\nDate', 'Cocoa\nPercent', 'Company\nLocation', 'Rating',
#        'Bean\nType', 'Broad Bean\nOrigin'],
#       dtype='object')

# %%
#get a list of columns 

flavors_cacao.columns
# Out:
# Index(['Company \n(Maker-if known)', 'Specific Bean Origin\nor Bar Name',
#        'REF', 'Review\nDate', 'Cocoa\nPercent', 'Company\nLocation', 'Rating',
#        'Bean\nType', 'Broad Bean\nOrigin'],
#       dtype='object')

# %%
# rename columns
flavors_cacao = flavors_cacao.rename(columns={"Company \n(Maker-if known)": "Company",
                                                      "Specific Bean Origin\nor Bar Name": "Specific Bean Origin",
                                                      "Review\nDate": "Review Date",
                                                      "Cocoa\nPercent": "Cocoa Percent",
                                                      "Company\nLocation": "Company Location",
                                                      "Bean\nType": "Bean Type",
                                                      "Broad Bean\nOrigin": "Broad Bean Origin"
                             })
flavors_cacao.columns = [c.replace('\n', ' ') for c in flavors_cacao.columns]
flavors_cacao.head()
# Out:
#   Company  (Maker-if known) Specific Bean Origin   REF  Review Date  \
# 0                  A. Morin          Agua Grande  1876         2016
# 1                  A. Morin                Kpime  1676         2015
# 2                  A. Morin               Atsane  1676         2015
# 3                  A. Morin                Akata  1680         2015
# 4                  A. Morin               Quilla  1704         2015
#
#   Cocoa Percent Company Location  Rating Bean Type Broad Bean Origin
# 0           63%           France    3.75                    Sao Tome
# 1           70%           France    2.75                        Togo
# 2           70%           France    3.00                        Togo
# 3           70%           France    3.50                        Togo
# 4           70%           France    3.50                        Peru

# %%
# fill space with NaN

flavors_cacao = flavors_cacao.replace(r'^\s*$', np.nan, regex=True)
flavors_cacao.head(10)
# Out:
#   Company  (Maker-if known) Specific Bean Origin   REF  Review Date  \
# 0                  A. Morin          Agua Grande  1876         2016
# 1                  A. Morin                Kpime  1676         2015
# 2                  A. Morin               Atsane  1676         2015
# 3                  A. Morin                Akata  1680         2015
# 4                  A. Morin               Quilla  1704         2015
# 5                  A. Morin             Carenero  1315         2014
# 6                  A. Morin                 Cuba  1315         2014
# 7                  A. Morin         Sur del Lago  1315         2014
# 8                  A. Morin       Puerto Cabello  1319         2014
# 9                  A. Morin              Pablino  1319         2014
#
#   Cocoa Percent Company Location  Rating Bean Type Broad Bean Origin
# 0           63%           France    3.75       NaN          Sao Tome
# 1           70%           France    2.75       NaN              Togo
# ...

# %%
flavors_cacao.columns
# Out:
# Index(['Company  (Maker-if known)', 'Specific Bean Origin', 'REF',
#        'Review Date', 'Cocoa Percent', 'Company Location', 'Rating',
#        'Bean Type', 'Broad Bean Origin'],
#       dtype='object')

# %%
# drop NaN values from the Broad Bean Origin column only

dropna_flavors_cacao = flavors_cacao.dropna(subset=['Broad Bean Origin'])

dropna_flavors_cacao.head(10)
# Out:
#   Company  (Maker-if known) Specific Bean Origin   REF  Review Date  \
# 0                  A. Morin          Agua Grande  1876         2016
# 1                  A. Morin                Kpime  1676         2015
# 2                  A. Morin               Atsane  1676         2015
# 3                  A. Morin                Akata  1680         2015
# 4                  A. Morin               Quilla  1704         2015
# 5                  A. Morin             Carenero  1315         2014
# 6                  A. Morin                 Cuba  1315         2014
# 7                  A. Morin         Sur del Lago  1315         2014
# 8                  A. Morin       Puerto Cabello  1319         2014
# 9                  A. Morin              Pablino  1319         2014
#
#   Cocoa Percent Company Location  Rating Bean Type Broad Bean Origin
# 0           63%           France    3.75       NaN          Sao Tome
# 1           70%           France    2.75       NaN              Togo
# ...

# %%
dropna_flavors_cacao['Bean Type'].value_counts()
# Out:
# Trinitario                  417
# Criollo                     152
# Forastero                    87
# Forastero (Nacional)         52
# Criollo, Trinitario          39
# Forastero (Arriba)           37
# Blend                        21
# Criollo (Porcelana)          10
# Trinitario, Criollo           9
# Forastero (Parazinho)         8
# Forastero (Arriba) ASS        6
# Matina                        3
# Beniano                       3
# Nacional (Arriba)             3
# EET                           3
# Amazon, ICS                   2
# Forastero (Catongo)           2
# Trinitario, Forastero         2
# Criollo, Forastero            2
# Criollo (Ocumare 61)          2
# Amazon mix                    2
# Trinitario (85% Criollo)      2
# Nacional                      2
# Criollo (Amarru)              2
# Forastero (Arriba) ASSS       1
# Trinitario (Scavina)          1
# Amazon                        1
# Forastero, Trinitario         1
# Forastero (Amelonado)         1
# ...

# %%
#replace bean name

dropna_flavors_cacao['Bean Type'] = dropna_flavors_cacao['Bean Type'].replace({
    'Forastero (Nacional)': 'Forastero', 'Forastero (Arriba)': 'Forastero',
     'Criollo (Porcelana)': 'Criollo', 'Forastero (Parazinho)': 'Forastero',
     'Forastero (Arriba) ASS': 'Forastero', 'Criollo (Amarru)': 'Criollo',
     'Nacional (Arriba)': 'Nacional', 'Amazon, ICS': 'Amazon',
     'Amazon mix': 'Amazon', 'Criollo (Ocumare 61)': 'Criollo',
     'Forastero (Catongo)': 'Forastero', 'Criollo (Ocumare 77)': 'Criollo',
     'Trinitario (85% Criollo)': 'Trinitario, Criollo', 'Blend-Forastero,Criollo': 'Criollo, Forastero',
     'Criollo (Wild)': 'Criollo', 'Forastero(Arriba, CCN)': 'Forastero',
     'Trinitario (Scavina)': 'Trinitario', 'Trinitario, TCGA': 'Trinitario',
     'Criollo (Ocumare 67)': 'Criollo', 'Forastero (Arriba) ASSS': 'Forastero',
     'Criollo, +': 'Criollo', 'Forastero (Amelonado)': 'Forastero',
     'Criollo (Ocumare)': 'Criollo', 'Trinitario (Amelonado)': 'Trinitario',
    'Trinitario, Criollo': 'Criollo, Trinitario', 'Trinitario, Forastero': 'Forastero, Trinitario'
   
    
})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
dropna_flavors_cacao['Bean Type'].value_counts()

#the most used beans are Trinitario,Forastero, Criollo  
# find average rating for each of them
# Out:
# Trinitario               420
# Forastero                195
# Criollo                  171
# Criollo, Trinitario       48
# Blend                     21
# Amazon                     5
# Nacional                   5
# Matina                     3
# EET                        3
# Criollo, Forastero         3
# Beniano                    3
# Forastero, Trinitario      3
# Trinitario, Criollo        2
# Trinitario, Nacional       1
# CCN51                      1
# Name: Bean Type, dtype: int64

# %%
dropna_flavors_cacao['Broad Bean Origin'].unique()
# Out:
# array(['Sao Tome', 'Togo', 'Peru', 'Venezuela', 'Cuba', 'Panama',
#        'Madagascar', 'Brazil', 'Ecuador', 'Colombia', 'Burma',
#        'Papua New Guinea', 'Bolivia', 'Fiji', 'Mexico', 'Indonesia',
#        'Trinidad', 'Vietnam', 'Nicaragua', 'Tanzania',
#        'Dominican Republic', 'Ghana', 'Belize', 'Jamaica', 'Grenada',
#        'Guatemala', 'Honduras', 'Costa Rica', 'Domincan Republic',
#        'Haiti', 'Congo', 'Philippines', 'Malaysia',
#        'Dominican Rep., Bali', 'Venez,Africa,Brasil,Peru,Mex', 'Gabon',
#        'Ivory Coast', 'Carribean', 'Sri Lanka', 'Puerto Rico', 'Uganda',
#        'Martinique', 'Sao Tome & Principe', 'Vanuatu', 'Australia',
#        'Liberia', 'Ecuador, Costa Rica', 'West Africa', 'Hawaii',
#        'St. Lucia', 'Cost Rica, Ven', 'Peru, Madagascar',
#        'Venezuela, Trinidad', 'Trinidad, Tobago',
#        'Ven, Trinidad, Ecuador', 'South America, Africa', 'India',
#        'Africa, Carribean, C. Am.', 'Tobago', 'Ven., Indonesia, Ecuad.',
# ...

# %%
dropna_flavors_cacao['Broad Bean Origin'] = dropna_flavors_cacao['Broad Bean Origin'].replace({'Domincan Republic': 'Dominican Republic', 'Dominican Rep., Bali': 'Dominican Republic',
    'Venez,Africa,Brasil,Peru,Mex': 'Venezuela', 'Sao Tome & Principe': 'Sao Tome',
    'Ecuador, Costa Rica': 'Ecuador', 'Cost Rica, Ven': 'Costa Rica',
    'Peru, Madagascar': 'Peru', 'Venezuela, Trinidad': 'Venezuela',
    'Trinidad, Tobago': 'Trinidad-Tobago', 'Ven, Trinidad, Ecuador': 'Venezuela',
    'South America, Africa': 'South America', 'Africa, Carribean, C. Am.': 'Africa',
    'Ven., Indonesia, Ecuad.': 'Venezuela', 'Peru, Ecuador, Venezuela': 'Peru',
    'Venezuela, Dom. Rep.': 'Venezuela', 'Colombia, Ecuador': 'Colombia',
    'Peru, Belize': 'Peru', 'Peru, Mad.': 'Peru',
    'Dom. Rep.': 'Dominican Republic', 'PNG, Vanuatu, Mad': 'PNG',
    'Ghana, Domin. Rep': 'Ghana', 'Trinidad, Ecuador': 'Trinidad-Tobago',
    'Venezuela, Java': 'Venezuela', 'Venezuela/ Ghana': 'Venezuela',
    'Venezuela, Ghana': 'Venezuela', 'Indonesia, Ghana': 'Indonesia',
    'Peru(SMartin,Pangoa,nacional)': 'Peru', 'Central and S. America': 'Central America',
    'Ven., Trinidad, Mad.': 'Venezuela', 'Carribean(DR/Jam/Tri)': 'Carribean',
    'Ghana & Madagascar': 'Ghana', 'Ven.,Ecu.,Peru,Nic.': 'Venezuela',
    'Madagascar & Ecuador': 'Madagascar', 'Guat., D.R., Peru, Mad., PNG': 'Guatemala',
    'Peru, Dom. Rep': 'Peru', 'Dom. Rep., Madagascar': 'Dominican Republic',
    'Gre., PNG, Haw., Haiti, Mad': 'Haiti', 'Mad., Java, PNG': 'Java',
    'Ven, Bolivia, D.R.': 'Venezuela', 'DR, Ecuador, Peru': 'Dominican Republic',
    'Peru, Ecuador':'Peru', 'Ecuador, Mad., PNG':'Ecuador',
    'Ghana, Panama, Ecuador':'Ghana', 'Venezuela, Carribean':'Venezuela', 'Peru, Mad., Dom. Rep.':'Peru'
})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dropna_flavors_cacao['Broad Bean Origin'].value_counts()
# Out:
# Venezuela             226
# Ecuador               195
# Peru                  172
# Dominican Republic    169
# Madagascar            146
# Nicaragua              60
# Brazil                 58
# Bolivia                57
# Belize                 49
# Colombia               43
# Papua New Guinea       42
# Costa Rica             39
# Vietnam                38
# Ghana                  37
# Tanzania               34
# Trinidad               33
# Mexico                 30
# Guatemala              29
# Hawaii                 28
# Jamaica                20
# Grenada                19
# Sao Tome               17
# Indonesia              17
# Honduras               15
# Cuba                   11
# Congo                  10
# Haiti                  10
# Carribean               9
# Fiji                    8
# Uganda                  8
# St. Lucia               8
# Vanuatu                 7
# Panama                  7
# West Africa             6
# Philippines             5
# ...

# %%
dropna_flavors_cacao['Company Location'].value_counts()
# Out:
# U.S.A.               737
# France               144
# Canada               117
# U.K.                  95
# Italy                 54
# Ecuador               54
# Australia             46
# Belgium               37
# Germany               35
# Switzerland           35
# Austria               23
# Colombia              23
# Hungary               22
# Spain                 21
# Venezuela             20
# Japan                 17
# Peru                  17
# New Zealand           17
# Madagascar            17
# Brazil                17
# Denmark               15
# Vietnam               11
# Guatemala             10
# Scotland              10
# Costa Rica             9
# Argentina              9
# Israel                 9
# Poland                 7
# Honduras               6
# Lithuania              6
# Sweden                 5
# Nicaragua              5
# Domincan Republic      5
# South Korea            5
# Puerto Rico            4
# Amsterdam              4
# Ireland                4
# ...

# %%
top_rating = dropna_flavors_cacao.sort_values(by='Rating', ascending=False)
top_rating.head(10)
# Out:
#      Company  (Maker-if known)                      Specific Bean Origin  \
# 78                      Amedei                                     Chuao
# 1276                    Patric                                Madagascar
# 719                   Fruition              Coto Brus, Heirloom, Batch 1
# 179              Benoit Nihant                             Rio Peripa H.
# 1544                      Soma   Three Amigos(Chuao, Wild Bolivia, D.R.)
# 180              Benoit Nihant  Bali, Sukrama Bros. Farm, Melaya, 62hr C
# 1543                      Soma                                  Peruvian
# 1699                  Valrhona                                   Guanaja
# 1393                     Rogue                  Silvestre, Batch 7, 2013
# 1240                    Pacari                   Sierra Nevada, Tutu Iku
#
#        REF  Review Date Cocoa Percent Company Location  Rating  \
# 78     111         2007           70%            Italy     5.0
# ...

# %%
top_rating_df = top_rating[['Cocoa Percent', 'Company Location', 'Rating', 'Bean Type', 'Broad Bean Origin']]
top_rating_df.head(20)

# I would like to represent the who are the best bean types, best country and cocoa percent
# remove index better
# Out:
#      Cocoa Percent Company Location  Rating            Bean Type  \
# 78             70%            Italy     5.0           Trinitario
# 1276           70%           U.S.A.     4.0           Trinitario
# 719            74%           U.S.A.     4.0               Amazon
# 179            73%          Belgium     4.0           Trinitario
# 1544           70%           Canada     4.0                  NaN
# 180            72%          Belgium     4.0           Trinitario
# 1543           64%           Canada     4.0                  NaN
# 1699           70%           France     4.0  Criollo, Trinitario
# 1393           75%           U.S.A.     4.0                  NaN
# 1240           70%          Ecuador     4.0                  NaN
# 861            74%      Switzerland     4.0              Criollo
# 186            72%      Switzerland     4.0                  NaN
# 1277           67%           U.S.A.     4.0                  NaN
# ...

# %%
tops_df_country =pd.pivot_table(top_rating_df,values=['Rating'],index=['Broad Bean Origin'],columns=['Bean Type'])

# math_scores_by_grade.index.name=None

tops_df_country 

# groupby
# Out:
#                    Rating                                      \
# Bean Type          Amazon   Beniano     Blend CCN51   Criollo
# Broad Bean Origin
# Belize              3.250       NaN       NaN   NaN  3.000000
# Bolivia             3.625  3.583333       NaN   NaN  3.187500
# Brazil                NaN       NaN       NaN   NaN       NaN
# Cameroon              NaN       NaN       NaN   NaN       NaN
# Carribean             NaN       NaN  3.000000   NaN       NaN
# Colombia              NaN       NaN       NaN   3.5       NaN
# Congo                 NaN       NaN       NaN   NaN  3.500000
# Costa Rica          3.750       NaN       NaN   NaN       NaN
# Cuba                  NaN       NaN       NaN   NaN  3.250000
# Dominican Republic    NaN       NaN  3.875000   NaN  3.750000
# Ecuador               NaN       NaN  3.000000   NaN  4.000000
# Fiji                  NaN       NaN       NaN   NaN       NaN
# Ghana                 NaN       NaN  2.500000   NaN       NaN
# ...

# %%
bottom_rating = dropna_flavors_cacao.sort_values(by='Rating', ascending=True)

bottom_rating.head(10)
# Out:
#      Company  (Maker-if known)            Specific Bean Origin   REF  \
# 326                  Callebaut                          Baking   141
# 437            Claudio Corallo                        Principe   252
# 324    Cacaoyere (Ecuatoriana)                       Pichincha   259
# 249     Bouga Cacao (Tulicorp)         El Oro, Hacienda de Oro   341
# 1492         Snake & Butterfly                           Ghana   693
# 449                  Coppeneur              Ecuador Puristique   817
# 988   Machu Picchu Trading Co.                            Peru   721
# 132        Artisan du Chocolat                 Brazil Rio Doce   363
# 125        Artisan du Chocolat                       Venezuela   486
# 828             Hotel Chocolat  Island Growers, 2012, 120hr c.  1113
#
#       Review Date Cocoa Percent Company Location  Rating   Bean Type  \
# 326          2007           70%          Belgium    1.00         NaN
# ...

# %%
bottom_rating_df = bottom_rating[['Cocoa Percent', 'Company Location', 'Rating', 'Bean Type', 'Broad Bean Origin']]

#bottom_rating_df.style.hide_index()
bottom_rating_df.head(10)

# I would like to represent the who are the worst bean types, worst country and cocoa percent
# Out:
#      Cocoa Percent Company Location  Rating   Bean Type Broad Bean Origin
# 326            70%          Belgium    1.00         NaN           Ecuador
# 437           100%         Sao Tome    1.00   Forastero          Sao Tome
# 324            91%          Ecuador    1.50   Forastero           Ecuador
# 249           100%          Ecuador    1.50   Forastero           Ecuador
# 1492           67%           U.S.A.    1.50   Forastero             Ghana
# 449           100%          Germany    1.50         NaN           Ecuador
# 988            70%             Peru    1.50         NaN              Peru
# 132            72%             U.K.    1.75         NaN            Brazil
# 125           100%             U.K.    1.75         NaN         Venezuela
# 828           100%             U.K.    1.75  Trinitario         St. Lucia

# %%
#keep only mostly used beans
beans_cacao_df = dropna_flavors_cacao[(dropna_flavors_cacao.values  == "Trinitario")|(dropna_flavors_cacao.values  == "Forastero" ) |(dropna_flavors_cacao.values  == "Criollo" )] 
beans_cacao_df
# Out:
#      Company  (Maker-if known)               Specific Bean Origin   REF  \
# 5                     A. Morin                           Carenero  1315
# 7                     A. Morin                       Sur del Lago  1315
# 8                     A. Morin                     Puerto Cabello  1319
# 11                    A. Morin                         Madagascar  1011
# 17                    A. Morin                              Chuao  1015
# ...                        ...                                ...   ...
# 1782                    Zotter  Satipo Pangoa region, 20hr conche   875
# 1784                    Zotter                             El Oro   879
# 1788                    Zotter                   Kongo, Highlands   883
# 1791                    Zotter                              Congo   749
# 1792                    Zotter                       Kerala State   749
#
#       Review Date Cocoa Percent Company Location  Rating   Bean Type  \
# ...

# %%
bean_df = beans_cacao_df[['Cocoa Percent', 'Company Location', 'Rating', 'Bean Type', 'Broad Bean Origin','Review Date']]

# bean_df.style.hide_index()

bean_df.head(10)
# Out:
#    Cocoa Percent Company Location  Rating   Bean Type Broad Bean Origin  \
# 5            70%           France    2.75     Criollo         Venezuela
# 7            70%           France    3.50     Criollo         Venezuela
# 8            70%           France    3.75     Criollo         Venezuela
# 11           70%           France    3.00     Criollo        Madagascar
# 17           70%           France    4.00  Trinitario         Venezuela
# 24           70%           U.S.A.    3.75     Criollo              Peru
# 25           60%             Fiji    2.75  Trinitario              Fiji
# 26           80%             Fiji    3.25  Trinitario              Fiji
# 27           88%             Fiji    3.50  Trinitario              Fiji
# 28           72%             Fiji    3.50  Trinitario              Fiji
#
#     Review Date
# 5          2014
# 7          2014
# 8          2014
# 11         2013
# 17         2013
# 24         2015
# 25         2011
# 26         2011
# 27         2011
# ...

# %%
tops_df_country =pd.pivot_table(bean_df,values=['Rating'],index=['Broad Bean Origin'],columns=['Bean Type'])

# math_scores_by_grade.index.name=None

tops_df_country.head(20)
# Out:
#                     Rating
# Bean Type          Criollo Forastero Trinitario
# Broad Bean Origin
# Belize              3.0000       NaN   3.231250
# Bolivia             3.1875       NaN   3.000000
# Brazil                 NaN  3.400000   3.200000
# Cameroon               NaN  3.250000        NaN
# Carribean              NaN       NaN   3.375000
# Colombia               NaN  2.950000   3.156250
# Congo               3.5000  3.305556        NaN
# Costa Rica             NaN  2.875000   3.375000
# Cuba                3.2500       NaN   3.400000
# Dominican Republic  3.7500  3.375000   3.250000
# Ecuador             4.0000  2.970149   3.111111
# Fiji                   NaN       NaN   3.125000
# Ghana                  NaN  3.104839   2.000000
# Grenada                NaN       NaN   3.088235
# Guatemala           3.5625       NaN   3.333333
# Hawaii              3.1250       NaN        NaN
# Honduras            3.7500       NaN   3.583333
# India                  NaN  3.500000        NaN
# ...

# %%
grouped_bean_df = bean_df.groupby(['Bean Type'])['Rating'].mean()

grouped_bean_df.mean()

# will do the mean for rating
# Out:
# 3.2085515605252444

# %%
size_bins = [0, 1, 2, 3, 4, 5]
group_names = ["Unpleasant", "Disappointing", "Satisfactory", "Premium", "Elite"]

# %% [markdown]
# Ricardo work

# %%
#x=[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]

# %%
ratings_per_year_bean_type=pd.pivot_table(beans_cacao_df,values=['Rating'],index=['Review Date'],columns=['Bean Type'])
ratings_per_year_bean_type
# Out:
#                Rating
# Bean Type     Criollo Forastero Trinitario
# Review Date
# 2006         3.428571  3.045455   3.250000
# 2007         3.687500  3.013158   3.362500
# 2008         3.136364  2.891667   3.140625
# 2009         3.195652  2.967391   3.212963
# 2010         2.972222  3.295455   3.166667
# 2011         3.440476  2.966667   3.270270
# 2012         3.125000  3.171053   3.256098
# 2013         3.132353  3.214286   3.342391
# 2014         3.300000  3.261364   3.194853
# 2015         3.333333  3.412500   3.236842
# 2016         3.196429  3.138889   3.280488
# 2017              NaN  3.500000   3.500000

# %%
ratings_per_year_bean_type_all=pd.pivot_table(beans_cacao_df,values=['Rating'],index=['Review Date'],
                                                      columns=['Company Location'],aggfunc='mean').mean(axis=1).reset_index()
ratings_per_year_bean_type_all
# Out:
#     Review Date         0
# 0          2006  3.103416
# 1          2007  3.195499
# 2          2008  3.049966
# 3          2009  3.059380
# 4          2010  3.214423
# 5          2011  3.252995
# 6          2012  3.185407
# 7          2013  3.375395
# 8          2014  3.317440
# 9          2015  3.371338
# 10         2016  3.209649
# 11         2017  3.500000

# %%
list_of_years=ratings_per_year_bean_type_all["Review Date"]
list_of_years
# Out:
# 0     2006
# 1     2007
# 2     2008
# 3     2009
# 4     2010
# 5     2011
# 6     2012
# 7     2013
# 8     2014
# 9     2015
# 10    2016
# 11    2017
# Name: Review Date, dtype: int64

# %%
rating_per_year_column=ratings_per_year_bean_type_all[0]
rating_per_year_column
# Out:
# 0     3.103416
# 1     3.195499
# 2     3.049966
# 3     3.059380
# 4     3.214423
# 5     3.252995
# 6     3.185407
# 7     3.375395
# 8     3.317440
# 9     3.371338
# 10    3.209649
# 11    3.500000
# Name: 0, dtype: float64

# %%
plt.title("Average rating per year for all beans")
plt.xlabel("Years")
plt.ylabel("Rating (%)")
plt.errorbar(list_of_years,rating_per_year_column, label="Average rating", marker="o")
plt.grid()
plt.legend()
plt.savefig("Average_rating_per_year_all_beans.png")
plt.show()

# %%
#ratings_per_year_bean_type=pd.pivot_table(beans_cacao_df,values=['Rating'],index=['Review Date'],
#                                                      columns=['Bean Type'])
#ratings_per_year_bean_type

# %%
ratings_per_year_bean_type
# Out:
#                Rating
# Bean Type     Criollo Forastero Trinitario
# Review Date
# 2006         3.428571  3.045455   3.250000
# 2007         3.687500  3.013158   3.362500
# 2008         3.136364  2.891667   3.140625
# 2009         3.195652  2.967391   3.212963
# 2010         2.972222  3.295455   3.166667
# 2011         3.440476  2.966667   3.270270
# 2012         3.125000  3.171053   3.256098
# 2013         3.132353  3.214286   3.342391
# 2014         3.300000  3.261364   3.194853
# 2015         3.333333  3.412500   3.236842
# 2016         3.196429  3.138889   3.280488
# 2017              NaN  3.500000   3.500000

# %%
list(ratings_per_year_bean_type.columns)
# Out:
# [('Rating', 'Criollo'), ('Rating', 'Forastero'), ('Rating', 'Trinitario')]

# %%
list(ratings_per_year_bean_type.columns)
# Out:
# [('Rating', 'Criollo'), ('Rating', 'Forastero'), ('Rating', 'Trinitario')]

# %%
plt.title("Average rating per type of bean")
plt.xlabel("Bean Type")
plt.ylabel("Rating (%)")
plt.errorbar(list_of_years,ratings_per_year_bean_type[('Rating','Criollo')] , label="Criollo", marker="o")
plt.errorbar(list_of_years,ratings_per_year_bean_type[('Rating','Forastero')] , label="Forastero", marker="o")
plt.errorbar(list_of_years,ratings_per_year_bean_type[('Rating','Trinitario')] , label="Trinitario", marker="o")
plt.grid()
plt.legend()
plt.savefig("Average_rating_per_type_of_beans_all_years.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=[6, 16])
sns.boxplot(
    data=beans_cacao_df,
    y='Broad Bean Origin',
    x='Rating'
)
ax.set_title('Boxplot, Rating for bean origin countries')
plt.savefig("ratings_for_bean_origin_countries_boxplot.png")

# %%
ratings_per_year_company_location=pd.pivot_table(beans_cacao_df,values=['Rating'],index=['Review Date'],
                                                      columns=['Company Location'])
ratings_per_year_company_location
# Out:
#                     Rating                                                \
# Company Location Amsterdam Argentina Australia Austria   Belgium  Brazil
# Review Date
# 2006                   NaN       NaN       NaN     NaN  3.125000     NaN
# 2007                   NaN       NaN       NaN     NaN  3.875000     NaN
# 2008                   NaN  3.321429       NaN     NaN  3.166667     NaN
# 2009                   NaN       NaN       NaN     NaN  3.000000     NaN
# 2010                   NaN       NaN       NaN     NaN  2.937500  3.5625
# 2011                   NaN       NaN  3.500000  3.2500  3.875000     NaN
# 2012                   NaN       NaN  3.250000  3.1875       NaN  3.5000
# 2013                   NaN       NaN  3.812500     NaN  3.625000  3.2500
# 2014                   NaN       NaN  2.750000     NaN  3.500000     NaN
# 2015                   3.5       NaN  3.450000     NaN  3.125000  3.5000
# 2016                   NaN       NaN  3.583333  3.1250       NaN  3.5000
# ...

# %%
list(ratings_per_year_company_location.columns)
# Out:
# [('Rating', 'Amsterdam'),
#  ('Rating', 'Argentina'),
#  ('Rating', 'Australia'),
#  ('Rating', 'Austria'),
#  ('Rating', 'Belgium'),
#  ('Rating', 'Brazil'),
#  ('Rating', 'Canada'),
#  ('Rating', 'Chile'),
#  ('Rating', 'Colombia'),
#  ('Rating', 'Costa Rica'),
#  ('Rating', 'Czech Republic'),
#  ('Rating', 'Ecuador'),
#  ('Rating', 'Eucador'),
#  ('Rating', 'Fiji'),
#  ('Rating', 'Finland'),
#  ('Rating', 'France'),
#  ('Rating', 'Germany'),
#  ('Rating', 'Ghana'),
#  ('Rating', 'Grenada'),
#  ('Rating', 'Guatemala'),
#  ('Rating', 'Hungary'),
#  ('Rating', 'Iceland'),
#  ('Rating', 'Ireland'),
#  ('Rating', 'Israel'),
#  ('Rating', 'Italy'),
#  ('Rating', 'Japan'),
#  ('Rating', 'Lithuania'),
#  ('Rating', 'Madagascar'),
#  ('Rating', 'Mexico'),
#  ('Rating', 'Netherlands'),
#  ('Rating', 'New Zealand'),
#  ('Rating', 'Nicaragua'),
#  ('Rating', 'Peru'),
#  ('Rating', 'Philippines'),
#  ('Rating', 'Poland'),
#  ('Rating', 'Portugal'),
#  ('Rating', 'Sao Tome'),
# ...

# %%
plt.title("Average rating of the Top 5 countries by higher consistent rating by year")
plt.xlabel("Years")
plt.ylabel("Rating (%)")
plt.errorbar(list_of_years,ratings_per_year_company_location[('Rating','France')] , label="France", marker="o")
plt.errorbar(list_of_years,ratings_per_year_company_location[('Rating','Italy')] , label="Italy", marker="o")
plt.errorbar(list_of_years,ratings_per_year_company_location[('Rating','Germany')] , label="Germany", marker="o")
plt.errorbar(list_of_years,ratings_per_year_company_location[('Rating','U.S.A.')] , label="U.S.A.", marker="o")
plt.errorbar(list_of_years,ratings_per_year_company_location[('Rating','Belgium')] , label="Belgium", marker="o")
plt.grid()
plt.legend()
plt.savefig("Average_rating_of_the_most_consistent_rating_counties_per_year.png")
plt.show()

# %%
ratings_per_year_company_location_agg=pd.pivot_table(beans_cacao_df,values=['Rating'],index=['Review Date'],
                                                      columns=['Company Location'],aggfunc='mean').mean(axis=1).reset_index()
ratings_per_year_company_location_agg
# Out:
#     Review Date         0
# 0          2006  3.103416
# 1          2007  3.195499
# 2          2008  3.049966
# 3          2009  3.059380
# 4          2010  3.214423
# 5          2011  3.252995
# 6          2012  3.185407
# 7          2013  3.375395
# 8          2014  3.317440
# 9          2015  3.371338
# 10         2016  3.209649
# 11         2017  3.500000

# %%
flow = pd.crosstab(
    beans_cacao_df['Company Location'],
    beans_cacao_df['Review Date'],
    beans_cacao_df['Rating'], aggfunc='mean'
)
flow['tot'] = flow.sum(axis=1)
flow = flow.sort_values('tot', ascending=False)
flow = flow.drop('tot', axis=1)

fig, ax = plt.subplots(figsize=[10,6])
sns.heatmap(flow.head(20), cmap='RdBu_r', linewidths=.5)
ax.set_title('Goods Flow from Company location, mean rating by years')
plt.savefig("Most_consistent_rating_countries_heatmap.png")

# %%
 fig, ax = plt.subplots(figsize=[6, 16])
sns.boxplot(
    data=beans_cacao_df,
    y='Company Location',
    x='Rating'
)
ax.set_title('Boxplot, Rating for Company Location countries')
plt.savefig("ratings_for_company_location_countries_boxplot.png")

# %% [markdown]
# --------------------James's plots----------------------
# #two dataset , one is from google dataset which is already cleaned up, the other is GDP of countries from Bloomberg

# %%
#two dataset , one is from google dataset which is already cleaned up, the other is GDP of countries from Bloomberg
# with chocolate dataset, use groupby and sort function to pick the top 10 chocolate bean origin countries with most reviews
#use loc function to find these countries' GDP data in GDP dataset 
#use join function to make a dataframe with top10 countries as index , number of reviews and avg GDP from last 10years as columns
#use matplotlib to plot, x number of reviews, y avg GDPs, to add country names on dots, need to write a function with a for loop
#top10 chocolate bean origin countries are developing countries, top10 produecer locations are in developed countries.
count_of_rating_by_origin = beans_cacao_df.groupby(["Broad Bean Origin"])
counts_rating_by_origin = pd.DataFrame(count_of_rating_by_origin["Rating"].count())
counts_rating_by_origin.reset_index(inplace=True)
#pick the top5 most reviews by bean origin 
counts_rating_by_origin = counts_rating_by_origin.rename(columns={"Rating":"counts_of_rating"})
rank_counts_rating_origin = counts_rating_by_origin.sort_values(by=['counts_of_rating'],ascending=False)
rank_counts_rating_origin.set_index("Broad Bean Origin", inplace=True)
most_counts_by_origin = rank_counts_rating_origin.iloc[0:10]
most_counts_by_origin.dropna()
# Out:
#                    counts_of_rating
# Broad Bean Origin
# Venezuela                       132
# Madagascar                      124
# Ecuador                          77
# Peru                             69
# Belize                           41
# Vietnam                          37
# Trinidad                         33
# Ghana                            32
# Brazil                           20
# Jamaica                          19

# %%
bean_origin_places = "GDP_bean_production_current$_v4-1.csv"
bean_origin_gdps = pd.read_csv(bean_origin_places)
bean_origin_gdps = bean_origin_gdps.rename(columns={"Broad Bean\nOrigin": "Broad Bean Origin"})
bean_origin_gdps = bean_origin_gdps.drop_duplicates()
bean_origin_gdps.set_index("Broad Bean Origin", inplace=True)
#bean_origin_gdps

# %%
top_origins = bean_origin_gdps.loc[["Venezuela","Ecuador","Peru","Madagascar","Trinidad","Vietnam","Brazil","Ghana","Belize","Jamaica"]]
top_origins = top_origins.drop_duplicates()
top_origins = top_origins.drop(columns=['Income group', 'Region'])
top_origins = top_origins.apply(pd.to_numeric)
top_origins['avg_gdp'] = top_origins.mean(axis=1)
top_origins_avg_gdp = pd.DataFrame(top_origins['avg_gdp'])
top_origins_avg_gdp['avg_gdp'] = top_origins_avg_gdp['avg_gdp']/(1000000000)
top_origins_avg_gdp = top_origins_avg_gdp.round(2)
top_origins_avg_gdp = top_origins_avg_gdp.rename(columns={'avg_gdp':'avg_gdp_in_billion'})
top_origins_avg_gdp
# Out:
#                    avg_gdp_in_billion
# Broad Bean Origin
# Venezuela                      230.92
# Ecuador                         82.09
# Peru                           166.36
# Madagascar                       9.53
# Trinidad                        23.66
# Vietnam                        152.38
# Brazil                        1971.54
# Ghana                           43.00
# Ghana                           43.00
# Belize                           1.56
# Jamaica                         13.82

# %%
gdp_vs_most_counts = most_counts_by_origin.join(top_origins_avg_gdp,how = "outer")
gdp_vs_most_counts.dropna()
# Out:
#                    counts_of_rating  avg_gdp_in_billion
# Broad Bean Origin
# Belize                           41                1.56
# Brazil                           20             1971.54
# Ecuador                          77               82.09
# Ghana                            32               43.00
# Ghana                            32               43.00
# Jamaica                          19               13.82
# Madagascar                      124                9.53
# Peru                             69              166.36
# Trinidad                         33               23.66
# Venezuela                       132              230.92
# Vietnam                          37              152.38

# %%
gdp_vs_most_counts = gdp_vs_most_counts.reset_index()
gdp_vs_most_counts = gdp_vs_most_counts.rename(columns={'Broad Bean Origin':'bean_origin'})
gdp_vs_most_counts
# Out:
#     index bean_origin  counts_of_rating  avg_gdp_in_billion
# 0       0      Belize                41                1.56
# 1       1      Brazil                20             1971.54
# 2       2     Ecuador                77               82.09
# 3       3       Ghana                32               43.00
# 4       4       Ghana                32               43.00
# 5       5     Jamaica                19               13.82
# 6       6  Madagascar               124                9.53
# 7       7        Peru                69              166.36
# 8       8    Trinidad                33               23.66
# 9       9   Venezuela               132              230.92
# 10     10     Vietnam                37              152.38

# %%
def label_point_orig(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['val']))

# %%
plt.scatter(gdp_vs_most_counts['counts_of_rating'], gdp_vs_most_counts['avg_gdp_in_billion'])
label_point_orig(gdp_vs_most_counts.counts_of_rating, gdp_vs_most_counts.avg_gdp_in_billion, gdp_vs_most_counts.bean_origin, plt)
plt.title(f'GDPs vs number of ratings by chocolate beans origin countries')
plt.xlabel('counts_of_rating')
plt.ylabel('average GDPs by billion')
plt.grid(True)
plt.savefig("GDPs of chocolate bean source countries.png")
plt.show()

# %%
rating_by_origin = beans_cacao_df.groupby(["Broad Bean Origin"])
mean_rating_by_origin = pd.DataFrame(rating_by_origin["Rating"].mean())
mean_rating_by_origin.reset_index(inplace=True)
mean_rating_by_origin
rank_mean_rating_origin = mean_rating_by_origin.sort_values(by=['Rating'],ascending=False)
rank_mean_rating_origin.set_index("Broad Bean Origin", inplace=True)
top_rating_by_origin = rank_mean_rating_origin.loc[["Venezuela","Ecuador","Peru","Madagascar","Trinidad","Vietnam","Brazil","Ghana","Belize","Jamaica"]]
top_rating_by_origin
# Out:
#                      Rating
# Broad Bean Origin
# Venezuela          3.301136
# Ecuador            3.000000
# Peru               3.224638
# Madagascar         3.272177
# Trinidad           3.204545
# Vietnam            3.317568
# Brazil             3.350000
# Ghana              3.070312
# Belize             3.225610
# Jamaica            3.171053

# %%
gdp_vs_top_ratings = top_rating_by_origin.join(top_origins_avg_gdp,how = "outer")
gdp_vs_top_ratings.dropna()
gdp_vs_top_ratings = gdp_vs_top_ratings.reset_index()
gdp_vs_top_ratings = gdp_vs_top_ratings.rename(columns={'Broad Bean Origin':'bean_origin'})
gdp_vs_top_ratings
# Out:
#    bean_origin    Rating  avg_gdp_in_billion
# 0       Belize  3.225610                1.56
# 1       Brazil  3.350000             1971.54
# 2      Ecuador  3.000000               82.09
# 3        Ghana  3.070312               43.00
# 4        Ghana  3.070312               43.00
# 5      Jamaica  3.171053               13.82
# 6   Madagascar  3.272177                9.53
# 7         Peru  3.224638              166.36
# 8     Trinidad  3.204545               23.66
# 9    Venezuela  3.301136              230.92
# 10     Vietnam  3.317568              152.38

# %%
plt.scatter(gdp_vs_top_ratings['Rating'], gdp_vs_top_ratings['avg_gdp_in_billion'])
label_point_orig(gdp_vs_top_ratings.Rating, gdp_vs_top_ratings.avg_gdp_in_billion, gdp_vs_top_ratings.bean_origin, plt)
plt.title(f'Average ratings vs. GDPs by bean origin countries')
plt.xlabel('ratings')
plt.ylabel('average GDPs in billion')
plt.grid(True)
plt.savefig("Ratings_vs_bean_origin_GDPs.png")
plt.show()

# %%
count_of_rating_by_company_loc = beans_cacao_df.groupby(["Company Location"])
counts_rating_by_company_loc = pd.DataFrame(count_of_rating_by_company_loc["Rating"].count())
counts_rating_by_company_loc.reset_index(inplace=True)
#pick the top5 most reviews by company location
counts_rating_by_company_loc = counts_rating_by_company_loc.rename(columns={"Rating":"counts_of_rating"})
rank_counts_rating_companyloc = counts_rating_by_company_loc.sort_values(by=['counts_of_rating'],ascending=False)
rank_counts_rating_companyloc.set_index("Company Location", inplace=True)
most_counts_by_companyloc = rank_counts_rating_companyloc.iloc[0:10]
most_counts_by_companyloc.dropna()
# Out:
#                   counts_of_rating
# Company Location
# U.S.A.                         265
# France                          70
# Canada                          53
# U.K.                            48
# Italy                           34
# Ecuador                         33
# Germany                         29
# Belgium                         27
# Australia                       24
# Switzerland                     24

# %%
bean_company_locations = "GDP_producers_current$_v2.csv"
bean_companyloc_gdps = pd.read_csv(bean_company_locations)
bean_companyloc_gdps = bean_companyloc_gdps.rename(columns={"Company\nLocation": "Company Location"})
bean_companyloc_gdps = bean_companyloc_gdps.drop_duplicates()
bean_companyloc_gdps.set_index("Company Location", inplace=True)
#bean_companyloc_gdps

# %%
top_companyloc = bean_companyloc_gdps.loc[["U.S.A.","France","Canada","U.K.","Italy","Ecuador","Germany","Belgium","Australia","Switzerland"]]
top_companyloc = top_companyloc.drop_duplicates()
top_companyloc = top_companyloc.drop(columns=['Income group', 'Region'])
top_companyloc = top_companyloc.apply(pd.to_numeric)
top_companyloc['avg_gdp'] = top_companyloc.mean(axis=1)
top_companyloc_avg_gdp = pd.DataFrame(top_companyloc['avg_gdp'])
top_companyloc_avg_gdp
# Out:
#                        avg_gdp
# Company Location
# U.S.A.            1.656154e+13
# France            2.670000e+12
# Canada            1.615385e+12
# Canada            1.615385e+12
# U.K.              2.741538e+12
# Italy             2.092308e+12
# Ecuador           8.209280e+10
# Germany           3.580769e+12
# Belgium           4.923077e+11
# Australia         1.234385e+12
# Switzerland       6.224615e+11

# %%
gdp_companyloc_vs_most_counts = most_counts_by_companyloc.join(top_companyloc_avg_gdp,how = "outer")
gdp_companyloc_vs_most_counts.dropna()
gdp_companyloc_vs_most_counts['avg_gdp'] = gdp_companyloc_vs_most_counts['avg_gdp']/(1000000000)
gdp_companyloc_vs_most_counts = gdp_companyloc_vs_most_counts.round(2)
gdp_companyloc_vs_most_counts = gdp_companyloc_vs_most_counts.rename(columns={'avg_gdp':'avg_gdp_in_billion'})
gdp_companyloc_vs_most_counts = gdp_companyloc_vs_most_counts.reset_index()
gdp_companyloc_vs_most_counts = gdp_companyloc_vs_most_counts.rename(columns={'Company Location':'company_loc'})
gdp_companyloc_vs_most_counts
# Out:
#     company_loc  counts_of_rating  avg_gdp_in_billion
# 0     Australia                24             1234.38
# 1       Belgium                27              492.31
# 2        Canada                53             1615.38
# 3        Canada                53             1615.38
# 4       Ecuador                33               82.09
# 5        France                70             2670.00
# 6       Germany                29             3580.77
# 7         Italy                34             2092.31
# 8   Switzerland                24              622.46
# 9          U.K.                48             2741.54
# 10       U.S.A.               265            16561.54

# %%
plt.scatter(gdp_companyloc_vs_most_counts['counts_of_rating'], gdp_companyloc_vs_most_counts['avg_gdp_in_billion'])
label_point_orig(gdp_companyloc_vs_most_counts.counts_of_rating, gdp_companyloc_vs_most_counts.avg_gdp_in_billion, gdp_companyloc_vs_most_counts.company_loc, plt)
plt.title(f'counts of ratings vs. GDPs of producers company location')
plt.xlabel('counts_of_rating')
plt.ylabel('average GDPs in billions')
plt.grid(True)
plt.savefig("Counts_of_ratings_vs_Company_location_GDPs.png")
plt.show()

# %%
rating_by_companyloc = beans_cacao_df.groupby(["Company Location"])
mean_rating_by_companyloc = pd.DataFrame(rating_by_companyloc["Rating"].mean())
mean_rating_by_companyloc.reset_index(inplace=True)
mean_rating_by_companyloc
rank_mean_rating_companyloc = mean_rating_by_companyloc.sort_values(by=['Rating'],ascending=False)
rank_mean_rating_companyloc.set_index("Company Location", inplace=True)
top_rating_by_companyloc = rank_mean_rating_companyloc.loc[["U.S.A.","France","Canada","U.K.","Italy","Ecuador","Germany","Belgium","Australia","Switzerland"]]
top_rating_by_companyloc
# Out:
#                     Rating
# Company Location
# U.S.A.            3.172642
# France            3.307143
# Canada            3.391509
# U.K.              3.067708
# Italy             3.360294
# Ecuador           2.848485
# Germany           3.267241
# Belgium           3.305556
# Australia         3.333333
# Switzerland       3.354167

# %%
gdp_companyloc_vs_top_ratings = top_rating_by_companyloc.join(top_companyloc_avg_gdp,how = "outer")
gdp_companyloc_vs_top_ratings.dropna()
gdp_companyloc_vs_top_ratings['avg_gdp'] = gdp_companyloc_vs_top_ratings['avg_gdp']/(1000000000)
gdp_companyloc_vs_top_ratings = gdp_companyloc_vs_top_ratings.round(2)
gdp_companyloc_vs_top_ratings = gdp_companyloc_vs_top_ratings.rename(columns={'avg_gdp':'avg_gdp_in_billion'})
gdp_companyloc_vs_top_ratings = gdp_companyloc_vs_top_ratings.reset_index()
gdp_companyloc_vs_top_ratings = gdp_companyloc_vs_top_ratings.rename(columns={'Company Location':'company_loc'})
gdp_companyloc_vs_top_ratings
# Out:
#     company_loc  Rating  avg_gdp_in_billion
# 0     Australia    3.33             1234.38
# 1       Belgium    3.31              492.31
# 2        Canada    3.39             1615.38
# 3        Canada    3.39             1615.38
# 4       Ecuador    2.85               82.09
# 5        France    3.31             2670.00
# 6       Germany    3.27             3580.77
# 7         Italy    3.36             2092.31
# 8   Switzerland    3.35              622.46
# 9          U.K.    3.07             2741.54
# 10       U.S.A.    3.17            16561.54

# %%
plt.scatter(gdp_companyloc_vs_top_ratings['Rating'], gdp_companyloc_vs_top_ratings['avg_gdp_in_billion'])
label_point_orig(gdp_companyloc_vs_top_ratings.Rating, gdp_companyloc_vs_top_ratings.avg_gdp_in_billion, gdp_companyloc_vs_top_ratings.company_loc, plt)
plt.title(f'ratings vs. GDPs of producers company location')
plt.xlabel('ratings')
plt.ylabel('average GDPs in billions')
plt.grid(True)
plt.savefig("Ratings_vs_bean_company_location_GDPs.png")
plt.show()
